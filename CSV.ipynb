# %%
b = open('data.csv','x')
b.close()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#      Name  Age    Address       Phone
# 0  Aayush   34  Kathmandu  9806754324
# 1   Shyam   23      Batan  9867453789
# 2    Hari   56       Bara  9805674324
# 3   Nabin   34     Siraha  9870654327
# 4    Sita   34  Bhaktapur  9876542345
# 5  Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5)
df
# Out:
#      Name  Age    Address       Phone
# 0  Aayush   34  Kathmandu  9806754324
# 1   Shyam   23      Batan  9867453789
# 2    Hari   56       Bara  9805674324
# 3   Nabin   34     Siraha  9870654327
# 4    Sita   34  Bhaktapur  9876542345

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#      Name  Age    Address       Phone
# 0  Aayush   34  Kathmandu  9806754324
# 1   Shyam   23      Batan  9867453789
# 2    Hari   56       Bara  9805674324
# 3   Nabin   34     Siraha  9870654327
# 4    Sita   34  Bhaktapur  9876542345

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head(3)               #3 ota read garx mathi batw
# Out:
#      Name  Age    Address       Phone
# 0  Aayush   34  Kathmandu  9806754324
# 1   Shyam   23      Batan  9867453789
# 2    Hari   56       Bara  9805674324

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.tail()                           #tala batw 5 ota read garx
# Out:
#      Name  Age    Address       Phone
# 1   Shyam   23      Batan  9867453789
# 2    Hari   56       Bara  9805674324
# 3   Nabin   34     Siraha  9870654327
# 4    Sita   34  Bhaktapur  9876542345
# 5  Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.tail(3)           #tala batw 3 ota value dinx
# Out:
#    Sn    Name  Age    Address       Phone
# 3   4   Nabin   34     Siraha  9870654327
# 4   5    Sita   34  Bhaktapur  9876542345
# 5   6  Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    Sn    Name  Age    Address       Phone
# 0   1  Aayush   34  Kathmandu  9806754324
# 1   2   Shyam   23      Batan  9867453789
# 2   3    Hari   56       Bara  9805674324
# 3   4   Nabin   34     Siraha  9870654327
# 4   5    Sita   34  Bhaktapur  9876542345
# 5   6  Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df
# Out:
#       Name  Age    Address       Phone
# Sn
# 1   Aayush   34  Kathmandu  9806754324
# 2    Shyam   23      Batan  9867453789
# 3     Hari   56       Bara  9805674324
# 4    Nabin   34     Siraha  9870654327
# 5     Sita   34  Bhaktapur  9876542345
# 6   Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn',usecols = ['Sn','Name','Phone'])
df
# Out:
#       Name       Phone
# Sn
# 1   Aayush  9806754324
# 2    Shyam  9867453789
# 3     Hari  9805674324
# 4    Nabin  9870654327
# 5     Sita  9876542345
# 6   Nabina  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.iloc[0:4]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1   Aayush   34  Kathmandu  9806754324
# 2    Shyam   23      Batan  9867453789
# 3     Hari   56       Bara  9805674324
# 4    Nabin   34     Siraha  9870654327

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.iloc[0:4,0:3]            #filter row and col
# Out:
#       Name  Age    Address
# Sn
# 1   Aayush   34  Kathmandu
# 2    Shyam   23      Batan
# 3     Hari   56       Bara
# 4    Nabin   34     Siraha

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df['Age']
# Out:
# Sn
# 1    34
# 2    23
# 3    56
# 4    34
# 5    34
# 6    23
# Name: Age, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df['Age']>30
# Out:
# Sn
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# Name: Age, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[df['Age']>30]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1   Aayush   34  Kathmandu  9806754324
# 3     Hari   56       Bara  9805674324
# 4    Nabin   34     Siraha  9870654327
# 5     Sita   34  Bhaktapur  9876542345

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[(df['Age']>30) & (df['Address']=='Bara')]
# Out:
#     Name  Age Address       Phone
# Sn
# 3   Hari   56    Bara  9805674324

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[(df['Age']>30) | (df['Address']=='Bara')]
# Out:
#       Name  Age    Address       Phone
# Sn
# 1   Aayush   34  Kathmandu  9806754324
# 3     Hari   56       Bara  9805674324
# 4    Nabin   34     Siraha  9870654327
# 5     Sita   34  Bhaktapur  9876542345
# 6   Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
data = df[(df['Age']>30) | (df['Address']=='Bara')]
data.to_csv('newdata.csv')

# %%
df.drop([1,2,3,4],axis=0)
# Out:
#       Name  Age    Address       Phone
# Sn
# 5     Sita   34  Bhaktapur  9876542345
# 6   Nabina   23       Bara  9856478453

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df.drop(["Sita","Nabin"],axis=0)
# Out:
#         Sn  Age    Address       Phone
# Name
# Aayush   1   34  Kathmandu  9806754324
# Shyam    2   23      Batan  9867453789
# Hari     3   56       Bara  9805674324
# Nabina   6   23       Bara  9856478453

# %%
#dataframe
import pandas as pd
d = {'Name':['Rama','Shyam','Hari','Bikash','Samrat'],
    'Address':['Kathmandu','Palpa','Pyuthan','Bhaktapur','Patan'],
    'Age':[21,22,20,19,18]}

df = pd.DataFrame(d)
df.to_csv('books.csv')
df.head()
# Out:
#      Name    Address  Age
# 0    Rama  Kathmandu   21
# 1   Shyam      Palpa   22
# 2    Hari    Pyuthan   20
# 3  Bikash  Bhaktapur   19
# 4  Samrat      Patan   18

# %%
#dictreader
import csv
csvfile = open('books.csv')
reader = csv.DictReader(csvfile)
for row in reader:
    print(dict(row))
# Out:
# {'': '0', 'Name': 'Rama', 'Address': 'Kathmandu', 'Age': '21'}
# {'': '1', 'Name': 'Shyam', 'Address': 'Palpa', 'Age': '22'}
# {'': '2', 'Name': 'Hari', 'Address': 'Pyuthan', 'Age': '20'}
# {'': '3', 'Name': 'Bikash', 'Address': 'Bhaktapur', 'Age': '19'}
# {'': '4', 'Name': 'Samrat', 'Address': 'Patan', 'Age': '18'}

# %%
#DictWriter
import csv
csv_columns = ['Name','Age','Address']
dict = [
    {'Name':'Aayush', 'Age':23,'address':'Kathamandu'},
    {'Name':'Shyam', 'Age':33,'address':'Patan'}
]

csv_file=open("data.csv", 'w')
writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
writer.writeheader()
for data in dict:
    writer.writerow(data)

# %%
import csv
fields=['Kamal','28','Baluwatar']
f = open('books.csv', 'a')
x=csv.writer(f)
x.writerow(fields)
f.close()

# %%
import csv
a = [['Apple',100,3,300], ['Ball',29,4,116]]
f = open('books.csv','w')
x = csv.writer(f)
for i in a:
    x.writerow(i)
f.close()
